# %%
import pandas as ps
from IPython.display import Image
import os
# To plot pretty figures
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="whitegrid") #White Grid
mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)

# Where to save the figures
PROJECT_ROOT_DIR = "."
CHAPTER_ID= "ProgettoFifa19"
IMAGES_PATH = os.path.join(PROJECT_ROOT_DIR, "images")
os.makedirs(IMAGES_PATH, exist_ok=True)

# %% [markdown]
# ============
#
# ## Terms of use
#
# Please carefully read the "Terms of use.txt" file to understand our terms of use of this data.
#
# ==================
#
# ## Meta Information:
#
# - We used paid workers from the Crowdflower crowdsourcing platform for labeling
# - At least three different workers were required to agree on a label before a task is finalized
# - We ran two tasks (as described below) for labeling
# - Please cite the below given paper, if you use any of these resources in your research
#
# ==================================
#
# ## Task # 1 Categories---Description:
#
# 1. Personal Only---if a message is only of interest to its author and her immediate circle of family/friends and does not convey any useful information to other people who do not know the author.
# 2. Informative (Direct)--- if the message is of interest to other people beyond the author's immediate circle, and seems to be written by a person who is a direct eyewitness of what is taking place.
# 3. Informative (Indirect)--- if the message is of interest to other people beyond the author's immediate circle, and seems to be seen/heard by the person on the radio, TV, newspaper, or other source. The message must specify the source.
# 4. Informative (Direct or Indirect)--- if the message is of interest to other people beyond the author's immediate circle, but there is not enough information to tell if it is a direct report or a repetition of something from another source.
# 5. Other--- if the message is not in English, or if it cannot be classified.
#
#
# ==================================
#
# ## Task # 2 Categories---Description:
#
# 1. Caution and advice---if a message conveys/reports information about some warning or a piece of advice about a possible hazard of an incident.
# 2. Casualties and damage---if a message reports the information about casualties or damage done by an incident.
# 3. Donations of money, goods or services---if a message speaks about money raised, donation offers, goods/services offered or asked by the victims of an incident.
# 4. People missing, found, or seen---if a message reports about the missing or found person effected by an incident or seen a celebrity visit on ground zero.
# 5. Information source---if a message conveys/contains some information sources like photo, footage, video, or mentions other sources like TV, radio related to an incident.
#
# =====================================================================================
#
# ## Please cite the following paper, if you use any of these resources in your research
#
# Muhammad Imran, Shady Elbassuoni, Carlos Castillo, Fernando Diaz and Patrick Meier. Practical Extraction of Disaster-Relevant Information from Social Media. In Social Web for Disaster Management (SWDM'13) - Co-located with WWW, May 2013, Rio de Janeiro, Brazil.

# %% [markdown]
# # Dataset 1
# 01_personal-informative-other/a143145.csv

# %%
dataset = ps.read_csv("SWDM2013_dataset/sandy2012_labeled_data/01_personal-informative-other/a143145.csv")
dataset.head()
# Out:
#     _unit_id  _golden _unit_state  _trusted_judgments    _last_judgment_at  \
# 0  221934923     True      golden                   3  11/13/2012 02:06:24
# 1  221934924     True      golden                   2  11/13/2012 02:16:03
# 2  221934925     True      golden                   2  11/13/2012 02:06:50
# 3  221934926     True      golden                   1  11/11/2012 01:44:50
# 4  221934927    False   finalized                   3  11/10/2012 12:38:04
#
#                choose_one  choose_one:confidence         choose_one_gold  nil  \
# 0           Personal Only                  1.000           Personal Only  NaN
# 1  Informative (Indirect)                  0.515  Informative (Indirect)  NaN
# 2           Personal Only                  1.000           Personal Only  NaN
# 3                   Other                  1.000  Informative (Indirect)  NaN
# 4  Informative (Indirect)                  1.000                     NaN  NaN
#
#                                           text_no_rt  \
# 0  ......................Ã¤Ã³Ã¬@Brains_x_Beauty: ...
# 1  At least 39 dead millions without power in San...
# 2  Clearly no one wants to look good for sandy la...
# 3  Hurricane #Sandy hits the Statue Of Liberty ht...
# 4  Watch Hurricane #Sandy prowling the East Coast...
#
#                                                tweet            user
# 0  RT @TheHolyKaron: ......................Ã¤Ã³Ã¬...      ____DatPMF
# 1  At least 39 dead millions without power in San...  _3091004140882
# 2  Clearly no one wants to look good for sandy la...    _JordanDawn_
# 3  RT @ImJay_wbu: Hurricane #Sandy hits the Statu...      _k4typerry
# 4  RT @NASA: Watch Hurricane #Sandy prowling the ...      _KieranJD_

# %%
dataset.shape
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   _unit_id               1000 non-null   int64
#  1   _golden                1000 non-null   bool
#  2   _unit_state            1000 non-null   object
#  3   _trusted_judgments     1000 non-null   int64
#  4   _last_judgment_at      1000 non-null   object
#  5   choose_one             1000 non-null   object
#  6   choose_one:confidence  1000 non-null   float64
#  7   choose_one_gold        51 non-null     object
#  8   nil                    1 non-null      object
#  9   text_no_rt             1000 non-null   object
#  10  tweet                  1000 non-null   object
#  11  user                   1000 non-null   object
# dtypes: bool(1), float64(1), int64(2), object(8)
# memory usage: 87.0+ KB

# %%
DS=dataset.drop('nil',axis=1)
DS
# Out:
#       _unit_id  _golden _unit_state  _trusted_judgments    _last_judgment_at  \
# 0    221934923     True      golden                   3  11/13/2012 02:06:24
# 1    221934924     True      golden                   2  11/13/2012 02:16:03
# 2    221934925     True      golden                   2  11/13/2012 02:06:50
# 3    221934926     True      golden                   1  11/11/2012 01:44:50
# 4    221934927    False   finalized                   3  11/10/2012 12:38:04
# ..         ...      ...         ...                 ...                  ...
# 995  221941935    False   finalized                   3  11/10/2012 23:43:00
# 996  221941936    False   finalized                   4  11/10/2012 22:29:50
# 997  221941937    False   finalized                   4  11/11/2012 06:41:18
# 998  221941938    False   finalized                   3  11/12/2012 21:26:10
# 999  221941939    False   finalized                   3  11/11/2012 16:24:26
#
#                            choose_one  choose_one:confidence  \
# 0                       Personal Only                 1.0000
# 1              Informative (Indirect)                 0.5150
# 2                       Personal Only                 1.0000
# 3                               Other                 1.0000
# 4              Informative (Indirect)                 1.0000
# ..                                ...                    ...
# 995            Informative (Indirect)                 1.0000
# 996                     Personal Only                 0.7401
# 997  Informative (Direct or Indirect)                 0.7597
# 998            Informative (Indirect)                 0.6521
# 999                     Personal Only                 0.6546
#
#             choose_one_gold  \
# 0             Personal Only
# 1    Informative (Indirect)
# 2             Personal Only
# 3    Informative (Indirect)
# 4                       NaN
# ..                      ...
# 995                     NaN
# 996                     NaN
# 997                     NaN
# 998                     NaN
# 999                     NaN
#
#                                             text_no_rt  \
# 0    ......................Ã¤Ã³Ã¬@Brains_x_Beauty: ...
# 1    At least 39 dead millions without power in San...
# 2    Clearly no one wants to look good for sandy la...
# 3    Hurricane #Sandy hits the Statue Of Liberty ht...
# 4    Watch Hurricane #Sandy prowling the East Coast...
# ..                                                 ...
# 995  LATEST | Airports and stock exchange reopen; N...
# 996  I'm sorry for all those who are suffering due ...
# 997                looks like sandy has hit stourport!
# 998  The Voice : Hurricane Sandy Caused by Global W...
# 999  Still hanging in there. No power. Reading lots...
#
#                                                  tweet            user
# 0    RT @TheHolyKaron: ......................Ã¤Ã³Ã¬...      ____DatPMF
# 1    At least 39 dead millions without power in San...  _3091004140882
# 2    Clearly no one wants to look good for sandy la...    _JordanDawn_
# 3    RT @ImJay_wbu: Hurricane #Sandy hits the Statu...      _k4typerry
# 4    RT @NASA: Watch Hurricane #Sandy prowling the ...      _KieranJD_
# ..                                                 ...             ...
# 995  LATEST | Airports and stock exchange reopen; N...      TheSunNews
# 996  I'm sorry for all those who are suffering due ...  garfield_kathy
# 997                looks like sandy has hit stourport!    kathsandford
# 998  The Voice : Hurricane Sandy Caused by Global W...    MainStMonroe
# 999  Still hanging in there. No power. Reading lots...  evening_shadow
#
# [1000 rows x 11 columns]

# %% [markdown]
# # Dataset 2
# 02_informative_caution-infosrc-donation-damage-other/a144267.csv

# %%
dataset = ps.read_csv("SWDM2013_dataset/sandy2012_labeled_data/02_informative_caution-infosrc-donation-damage-other/a144267.csv")
dataset.head()
# Out:
#     _unit_id  _golden _unit_state  _trusted_judgments    _last_judgment_at  \
# 0  223607030    False   finalized                   3  11/14/2012 03:26:51
# 1  223607031     True      golden                   3  11/14/2012 03:41:27
# 2  223607032    False   finalized                   3  11/14/2012 03:38:40
# 3  223607033     True      golden                  10  11/14/2012 03:35:39
# 4  223607034     True      golden                   7  11/14/2012 03:36:35
#
#                               choose_one  choose_one:confidence  \
# 0                  Casualties and damage                 1.0000
# 1                  Casualties and damage                 1.0000
# 2                  Casualties and damage                 0.6849
# 3                     Caution and advice                 0.8900
# 4  Donations of money, goods or services                 0.5727
#
#                          choose_one_gold  \
# 0                                    NaN
# 1                  Casualties and damage
# 2                                    NaN
# 3                     Caution and advice
# 4  Donations of money, goods or services
#
#                                           text_no_rt  \
# 0  28 deaths due to Hurricane Sandy | Charlotte t...
# 1  Sandy kills 50 people nationwide 18 were New Y...
# 2  RT @nowthised: Wider shot of scaffolding toppl...
# 3  #Sandy will be onshore about 6pm. Slightly fas...
# 4  @ChrisFRC lost startups can go to @AlleyNYC. T...
#
#                                                tweet  \
# 0  RT @HenderGrande: 28 deaths due to Hurricane S...
# 1  Sandy kills 50 people nationwide 18 were New Y...
# 2  RT @twc_hurricane: RT @nowthised: Wider shot o...
# 3  RT @growingwisdom: #Sandy will be onshore abou...
# 4  @ChrisFRC lost startups can go to @AlleyNYC. T...
#
#                                type            user
# 0  Informative (Direct or Indirect)  1EmmaHenderson
# 1  Informative (Direct or Indirect)           9NEWS
# 2  Informative (Direct or Indirect)    AbrahamAkiva
# 3  Informative (Direct or Indirect)       aecheylon
# 4  Informative (Direct or Indirect)     AHolidayiii

# %%
dataset.shape
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 543 entries, 0 to 542
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   _unit_id               543 non-null    int64
#  1   _golden                543 non-null    bool
#  2   _unit_state            543 non-null    object
#  3   _trusted_judgments     543 non-null    int64
#  4   _last_judgment_at      543 non-null    object
#  5   choose_one             543 non-null    object
#  6   choose_one:confidence  543 non-null    float64
#  7   choose_one_gold        41 non-null     object
#  8   text_no_rt             543 non-null    object
#  9   tweet                  543 non-null    object
#  10  type                   543 non-null    object
#  11  user                   543 non-null    object
# dtypes: bool(1), float64(1), int64(2), object(8)
# memory usage: 47.3+ KB

# %% [markdown]
# # Dataset 3
# 03_caution-n-advice_classify-extract/a146283.csv

# %%
dataset = ps.read_csv("SWDM2013_dataset/sandy2012_labeled_data/03_caution-n-advice_classify-extract/a146283.csv")
dataset.head()
# Out:
#     _unit_id  _golden _unit_state  _trusted_judgments    _last_judgment_at  \
# 0  227175857     True      golden                   8   12/8/2012 19:09:26
# 1  227175859    False      golden                   1  11/25/2012 17:31:06
# 2  227175860     True      golden                  34  12/10/2012 06:05:12
# 3  227175862     True      golden                  31  12/10/2012 06:08:53
# 4  227175867    False      golden                   1  11/25/2012 17:24:06
#
#                                               source  \
# 0             #sandy\nN/A\nN/A\nn/a\nN/A\n\nN/A\nn/a
# 1                                                NaN
# 2  \nn/a\n\n#Sandy\nn/a\nn/a\n#Sandy\n#Sandy\n\n\...
# 3  n/a\n\n#Sandy\n#Sandy\nN/A\n\n\n\n\nN/A\n\nN/A...
# 4                                                NaN
#
#                 type_of_advice_or_caution  \
# 0  A hurricane sighting has been reported
# 1                                   Other
# 2  A hurricane sighting has been reported
# 3                                   Other
# 4  A hurricane sighting has been reported
#
#    type_of_advice_or_caution:confidence  \
# 0                                0.7629
# 1                                1.0000
# 2                                0.7427
# 3                                0.9531
# 4                                1.0000
#
#                                                 what  \
# 0  Storm just now hitting Jersey\nAll bridges clo...
# 1  Hurricane Sandy is going to fill the subways w...
# 2  NYC is now impacted by hurricane\nimpacted\nhu...
# 3  stock market closing\nstock market closing for...
# 4                                    Hurricane Sandy
#
#                                                 when  ...  \
# 0   now\nnow\njust now\nn/a\nN/A\nnow\nnow\njust now  ...
# 1                                                NaN  ...
# 2  now\nnow\n\nnow\nn/a\nn/a\nN/A\nnow\n\nnow\nno...  ...
# 3  n/a\n\nna\nN/A\nN/A\n\n1988\n\n\nN/A\n\nN/A\ns...  ...
# 4                                                NaN  ...
#
#                            category source_gold  \
# 0  Informative (Direct or Indirect)         NaN
# 1  Informative (Direct or Indirect)         NaN
# 2  Informative (Direct or Indirect)         NaN
# 3  Informative (Direct or Indirect)         NaN
# 4  Informative (Direct or Indirect)         NaN
#
#                                           text_no_rt  \
# 0  Storm just now hitting Jersey...Milford is fee...
# 1  Hurricane Sandy is going to fill the subways w...
# 2        Omg NYC is now impacted by hurricane #Sandy
# 3  First time since 1888 stock market closing for...
# 4  Hurricane Sandy or else Frankestorm heading to...
#
#                                                tweet                type  \
# 0  Storm just now hitting Jersey...Milford is fee...  Caution and advice
# 1  RT @JessieWessie33: Hurricane Sandy is going t...  Caution and advice
# 2        Omg NYC is now impacted by hurricane #Sandy  Caution and advice
# 3  First time since 1888 stock market closing for...  Caution and advice
# 4  RT @KateNinaA: Hurricane Sandy or else Frankes...  Caution and advice
#
#                   type_of_advice_or_caution_gold          user  \
# 0         A hurricane sighting has been reported        beball
# 1                                          Other    britthanus
# 2         A hurricane sighting has been reported      BuniYani
# 3                                          Other  feverplay_xo
# 4  A hurricane sighting has been reported\nOther    LuciiAgudo
#
#                                            what_gold when_gold  \
# 0  hitting Jersey\nAll bridges closing in NYC & J...       now
# 1                        fill the subways with water       NaN
# 2  Impacted\nNYC is now impacted by hurricane\nim...       Now
# 3  stock market closing\nstock market closing for...  N/A\nn/a
# 4                Hurricane Sandy or else Frankestorm       NaN
#
#                           where_gold
# 0  NYC\nJersey\nJersey\nNYC & Jersey
# 1                                NYC
# 2                           NYC\nNYC
# 3                           N/A\nn/a
# 4                 heading toward NYC
#
# [5 rows x 21 columns]

# %%
dataset.shape
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126 entries, 0 to 125
# Data columns (total 21 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   _unit_id                              126 non-null    int64
#  1   _golden                               126 non-null    bool
#  2   _unit_state                           126 non-null    object
#  3   _trusted_judgments                    126 non-null    int64
#  4   _last_judgment_at                     126 non-null    object
#  5   source                                122 non-null    object
#  6   type_of_advice_or_caution             126 non-null    object
#  7   type_of_advice_or_caution:confidence  126 non-null    float64
#  8   what                                  126 non-null    object
#  9   when                                  123 non-null    object
#  10  where                                 126 non-null    object
#  11  category                              126 non-null    object
#  12  source_gold                           5 non-null      object
#  13  text_no_rt                            126 non-null    object
#  14  tweet                                 126 non-null    object
#  15  type                                  126 non-null    object
#  16  type_of_advice_or_caution_gold        13 non-null     object
#  17  user                                  126 non-null    object
#  18  what_gold                             13 non-null     object
#  19  when_gold                             9 non-null      object
#  20  where_gold                            11 non-null     object
# dtypes: bool(1), float64(1), int64(2), object(17)
# memory usage: 19.9+ KB

# %% [markdown]
# # Dataset 3
# 03_damage-n-casualties_classify-extract/a146281.csv

# %%
dataset = ps.read_csv("SWDM2013_dataset/sandy2012_labeled_data/03_damage-n-casualties_classify-extract/a146281.csv")
dataset.head()
# Out:
#     _unit_id  _golden _unit_state  _trusted_judgments    _last_judgment_at  \
# 0  227175113     True      golden                  12  11/23/2012 14:36:01
# 1  227175114     True      golden                  12  11/23/2012 13:13:34
# 2  227175115     True      golden                   7  11/23/2012 09:09:19
# 3  227175116     True      golden                  11  11/23/2012 13:20:51
# 4  227175117     True      golden                  15  11/23/2012 14:25:53
#
#                   hom_many_injured_or_dead_if_people  \
# 0     28\n28\n28\n28\n28\n28\n28\n28\n28\n28\n28\n28
# 1  50\n50\n50\n50 people nationwide 18 were New Y...
# 2                                       \n\n\n\n\n\n
# 3     \n\n\n\nnone\n\ntoll climbs\n\n\n\ntoll climbs
# 4                       \n\n\n\n\n\n\n\n\n\n\n\n\n\n
#
#                             people_or_infrastructure  \
# 0                                       People: dead
# 1                     Both people and infrastructure
# 2  Infrastructure (building, bridge, road, etc.) ...
# 3                     Both people and infrastructure
# 4  Infrastructure (building, bridge, road, etc.) ...
#
#    people_or_infrastructure:confidence  \
# 0                               1.0000
# 1                               0.7143
# 2                               0.5353
# 3                               0.5651
# 4                               1.0000
#
#    what_infrastructure_was_damaged_if_infrastructure  \
# 0                             \n\n\n\n\n\n\n\n\n\n\n
# 1  homes\n\n8 million homes\n8 million homes stil...
# 2  \nscaffolding toppling car\nshot of scaffoldin...
# 3  homes\npower, homes\nThousands of homes\nhomes...
# 4  Extensive flooding in all subway tunnels\nExte...
#
#                            category  \
# 0  Informative (Direct or Indirect)
# 1  Informative (Direct or Indirect)
# 2  Informative (Direct or Indirect)
# 3  Informative (Direct or Indirect)
# 4  Informative (Direct or Indirect)
#
#              hom_many_injured_or_dead_if_people_gold  \
# 0                                                 28
# 1  50\nkills 50 people nationwide\n50 people nati...
# 2                                                NaN
# 3                                           N/A\nN/a
# 4                                                NaN
#
#                        people_or_infrastructure_gold  \
# 0                                       People: dead
# 1       People: dead\nBoth people and infrastructure
# 2  Infrastructure (building, bridge, road, etc.) ...
# 3                     Both people and infrastructure
# 4  Infrastructure (building, bridge, road, etc.) ...
#
#                                           text_no_rt  \
# 0  28 deaths due to Hurricane Sandy | Charlotte t...
# 1  Sandy kills 50 people nationwide 18 were New Y...
# 2  RT @nowthised: Wider shot of scaffolding toppl...
# 3  Sandy death toll climbs; millions remain witho...
# 4  Extensive flooding in all subway tunnels says ...
#
#                                                tweet                   type  \
# 0  RT @HenderGrande: 28 deaths due to Hurricane S...  Casualties and damage
# 1  Sandy kills 50 people nationwide 18 were New Y...  Casualties and damage
# 2  RT @twc_hurricane: RT @nowthised: Wider shot o...  Casualties and damage
# 3  Sandy death toll climbs; millions remain witho...  Casualties and damage
# 4  RT @emmagkeller: Extensive flooding in all sub...  Casualties and damage
#
#              user what_infrastructure_was_damaged_if_infrastructure_gold
# 0  1EmmaHenderson                                                NaN
# 1           9NEWS   8 million homes still without power\n8 millio...
# 2    AbrahamAkiva  scaffolding toppling car\nshot of scaffolding ...
# 3   alexandermimi  millions remain without power = electricity da...
# 4        alischaw  all subway tunnels\nExtensive flooding in all ...

# %%
dataset.shape
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 170 entries, 0 to 169
# Data columns (total 17 columns):
#  #   Column                                                  Non-Null Count  Dtype
# ---  ------                                                  --------------  -----
#  0   _unit_id                                                170 non-null    int64
#  1   _golden                                                 170 non-null    bool
#  2   _unit_state                                             170 non-null    object
#  3   _trusted_judgments                                      170 non-null    int64
#  4   _last_judgment_at                                       170 non-null    object
#  5   hom_many_injured_or_dead_if_people                      170 non-null    object
#  6   people_or_infrastructure                                170 non-null    object
#  7   people_or_infrastructure:confidence                     170 non-null    float64
#  8   what_infrastructure_was_damaged_if_infrastructure       170 non-null    object
#  9   category                                                170 non-null    object
#  10  hom_many_injured_or_dead_if_people_gold                 12 non-null     object
#  11  people_or_infrastructure_gold                           32 non-null     object
#  12  text_no_rt                                              170 non-null    object
#  13  tweet                                                   170 non-null    object
#  14  type                                                    170 non-null    object
#  15  user                                                    170 non-null    object
#  16  what_infrastructure_was_damaged_if_infrastructure_gold  21 non-null     object
# dtypes: bool(1), float64(1), int64(2), object(13)
# memory usage: 21.5+ KB

# %% [markdown]
# # Dataset 3
# 03_infosrc_classify-extract/a146274.csv

# %%
dataset = ps.read_csv("SWDM2013_dataset/sandy2012_labeled_data/03_infosrc_classify-extract/a146274.csv")
dataset.head()
# Out:
#     _unit_id  _golden _unit_state  _trusted_judgments    _last_judgment_at  \
# 0  227174029     True      golden                   7  11/25/2012 07:05:36
# 1  227174030     True      golden                   5  11/25/2012 07:13:17
# 2  227174031     True      golden                   6  11/24/2012 04:04:24
# 3  227174032     True      golden                   1  11/24/2012 22:17:12
# 4  227174033     True      golden                   2  11/23/2012 02:49:17
#
#                       type_of_message  type_of_message:confidence  \
# 0                   None of the above                      0.8817
# 1  Look at this photo or these photos                      0.4002
# 2                   None of the above                      0.6951
# 3  Look at this video or these videos                      1.0000
# 4          Look at this web site/page                      0.5455
#
#                    url_or_name_of_the_stationchannel  \
# 0                   N/A\nn/a\nN/A\nN/A\nNA\nN/A\nN/A
# 1  http://t.co/j6I531we\nhttp://t.co/j6I531we\nN/...
# 2                       n/a\nN/A\nN/A\nN/A\nN/A\nN/A
# 3                               http://t.co/eofIJ7Fe
# 4         http://t.co/eCGqw1ek\nhttp://t.co/eCGqw1ek
#
#                                                 what  \
# 0  sandy was a weak ass bitch\nsandy was a weak a...
# 1  Hurricane #Sandy hits NYC hard with intense wi...
# 2  press conference LIVE now on #Sandy aftermath....
# 3                                  Statue of Liberty
# 4  images from the empty #NYC subways\nfrom the e...
#
#                            category  \
# 0  Informative (Direct or Indirect)
# 1  Informative (Direct or Indirect)
# 2  Informative (Direct or Indirect)
# 3  Informative (Direct or Indirect)
# 4              Informative (Direct)
#
#                                           text_no_rt  \
# 0  checked the news. yes there is schol tomoro. s...
# 1  Hurricane #Sandy hits NYC hard with intense wi...
# 2  Mayor Bloomberg holding press conference LIVE ...
# 3  RT @mrspantsworth: Statue of Liberty Torchcam ...
# 4  even the rats left town RT @YGNw: Eery images ...
#
#                                                tweet                type  \
# 0  checked the news. yes there is schol tomoro. s...  Information Source
# 1  Hurricane #Sandy hits NYC hard with intense wi...  Information Source
# 2  RT @HuffingtonPost: Mayor Bloomberg holding pr...  Information Source
# 3  RT @dirtymondaze: RT @mrspantsworth: Statue of...  Information Source
# 4  even the rats left town RT @YGNw: Eery images ...  Information Source
#
#                                 type_of_message_gold  \
# 0                                  None of the above
# 1  Look at this photo or these photos\nNone of th...
# 2                                  None of the above
# 3                         Look at this web site/page
# 4                 Look at this photo or these photos
#
#   url_or_name_of_the_stationchannel_gold             user  \
# 0                                    NaN   BrandoCummando
# 1                   http://t.co/j6I531we       davidfig79
# 2                                    NaN  HurricSandyNews
# 3                   http://t.co/eofIJ7Fe         loloster
# 4                   http://t.co/eCGqw1ek        dc_fusion
#
#                                  what_gold
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3         some idea of the force of #sandy
# 4  Eery images from the empty #NYC subways

# %%
dataset.shape
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70 entries, 0 to 69
# Data columns (total 17 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   _unit_id                                70 non-null     int64
#  1   _golden                                 70 non-null     bool
#  2   _unit_state                             70 non-null     object
#  3   _trusted_judgments                      70 non-null     int64
#  4   _last_judgment_at                       70 non-null     object
#  5   type_of_message                         70 non-null     object
#  6   type_of_message:confidence              70 non-null     float64
#  7   url_or_name_of_the_stationchannel       70 non-null     object
#  8   what                                    70 non-null     object
#  9   category                                70 non-null     object
#  10  text_no_rt                              70 non-null     object
#  11  tweet                                   70 non-null     object
#  12  type                                    70 non-null     object
#  13  type_of_message_gold                    29 non-null     object
#  14  url_or_name_of_the_stationchannel_gold  24 non-null     object
#  15  user                                    70 non-null     object
#  16  what_gold                               23 non-null     object
# dtypes: bool(1), float64(1), int64(2), object(13)
# memory usage: 8.9+ KB

# %% [markdown]
# # Dataset 4
# 04_combined_classification/a154774.csv

# %%
dataset = ps.read_csv("SWDM2013_dataset/sandy2012_labeled_data/04_combined_classification/a154774.csv")
dataset.head()
# Out:
#     _unit_id  _golden _unit_state  _trusted_judgments    _last_judgment_at  \
# 0  238841781    False   finalized                   4    1/2/2013 13:37:11
# 1  238841782    False   finalized                   4  12/24/2012 14:05:56
# 2  238841783    False   finalized                   4  12/24/2012 14:05:56
# 3  238841784     True      golden                  35    1/2/2013 13:30:06
# 4  238841785     True      golden                  28    1/2/2013 13:33:57
#
#   the_author_of_the_tweet_seems_to_be_an_eye_witness_of_the_event  \
# 0                                                NaN
# 1                                               True
# 2                                               True
# 3                                               True
# 4                                               True
#
#    the_author_of_the_tweet_seems_to_be_an_eye_witness_of_the_event:confidence  \
# 0                                                NaN
# 1                                                1.0
# 2                                                1.0
# 3                                                1.0
# 4                                                1.0
#
#                                      type_of_message  \
# 0  Informative: offers/gives donations of money, ...
# 1                     Not informative: personal only
# 2  Informative: information source with extensive...
# 3  Informative: damage (building, road, lines, etc.)
# 4    Can not judge (not in English, too short, etc.)
#
#    type_of_message:confidence  nil  \
# 0                      0.2689  NaN
# 1                      0.7772  NaN
# 2                      0.2554  NaN
# 3                      0.6938  NaN
# 4                      0.5661  NaN
#
#   the_author_of_the_tweet_seems_to_be_an_eye_witness_of_the_event_gold  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                                tweet  tweet_no  \
# 0  important --&gt; @JebBush suggests federal gov...     11899
# 1  @ChrisMara816: Screw #sandy we skipped right a...    116293
# 2  On The Learning Network Sandy as a Teaching To...      1091
# 3  RT @nytimes: More than 8 million homes in the ...     53537
# 4                 These Hurricane Sandy pages though    113571
#
#                                          tweet_no_rt  \
# 0  important --&gt; @JebBush suggests federal gov...
# 1  @ChrisMara816: Screw #sandy we skipped right a...
# 2  On The Learning Network Sandy as a Teaching To...
# 3  More than 8 million homes in the U.S. are now ...
# 4                 These Hurricane Sandy pages though
#
#                                 type_of_message_gold           user
# 0                                                NaN      danholler
# 1                                                NaN      kaatteexo
# 2                                                NaN    LotsToLearn
# 3  Informative: damage (building, road, lines, etc.)  brunamacedo06
# 4    Can not judge (not in English, too short, etc.)     CameronXCV

# %%
dataset.shape
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1987 entries, 0 to 1986
# Data columns (total 16 columns):
#  #   Column                                                                      Non-Null Count  Dtype
# ---  ------                                                                      --------------  -----
#  0   _unit_id                                                                    1987 non-null   int64
#  1   _golden                                                                     1987 non-null   bool
#  2   _unit_state                                                                 1987 non-null   object
#  3   _trusted_judgments                                                          1987 non-null   int64
#  4   _last_judgment_at                                                           1987 non-null   object
#  5   the_author_of_the_tweet_seems_to_be_an_eye_witness_of_the_event             375 non-null    object
#  6   the_author_of_the_tweet_seems_to_be_an_eye_witness_of_the_event:confidence  375 non-null    float64
#  7   type_of_message                                                             1987 non-null   object
#  8   type_of_message:confidence                                                  1987 non-null   float64
#  9   nil                                                                         1 non-null      object
#  10  the_author_of_the_tweet_seems_to_be_an_eye_witness_of_the_event_gold        2 non-null      object
#  11  tweet                                                                       1987 non-null   object
#  12  tweet_no                                                                    1987 non-null   int64
#  13  tweet_no_rt                                                                 1987 non-null   object
#  14  type_of_message_gold                                                        46 non-null     object
#  15  user                                                                        1987 non-null   object
# dtypes: bool(1), float64(2), int64(3), object(10)
# memory usage: 234.9+ KB

# %% [markdown]
# # Dataset 4
# 04_combined_classification/f154774.csv

# %%
dataset = ps.read_csv("SWDM2013_dataset/sandy2012_labeled_data/04_combined_classification/f154774.csv")
dataset.head()
# Out:
#     _unit_id          _created_at  _golden        _id _missed  \
# 0  238841781  12/24/2012 13:41:45    False  787060207     NaN
# 1  238841781  12/24/2012 13:44:17    False  787063467     NaN
# 2  238841781  12/24/2012 13:54:14    False  787076220     NaN
# 3  238841781    1/2/2013 13:37:11    False  797105603     NaN
# 4  238841782  12/24/2012 13:24:41    False  787038536     NaN
#
#            _started_at  _tainted       _channel  _trust  _worker_id  ...  \
# 0  12/24/2012 13:37:36     False        instagc  0.7333    14425455  ...
# 1  12/24/2012 13:39:45     False        instagc  0.8333    13441146  ...
# 2  12/24/2012 13:51:24     False  golddiggergpt  0.8182    11092052  ...
# 3    1/2/2013 13:34:10     False        instagc  0.7143    13166748  ...
# 4  12/24/2012 13:22:21     False        instagc  0.9048    14031300  ...
#
#               _ip  \
# 0  69.136.129.135
# 1    98.18.108.46
# 2   108.92.226.94
# 3   71.200.11.183
# 4   70.247.113.51
#
#   the_author_of_the_tweet_seems_to_be_an_eye_witness_of_the_event  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                               True
#
#                                      type_of_message  nil  \
# 0                                 Informative: other  NaN
# 1  Informative: offers/gives donations of money, ...  NaN
# 2  Informative: celebrities or authorities react ...  NaN
# 3                     Informative: caution or advice  NaN
# 4                     Not informative: personal only  NaN
#
#   the_author_of_the_tweet_seems_to_be_an_eye_witness_of_the_event_gold  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                                tweet tweet_no  \
# 0  important --&gt; @JebBush suggests federal gov...    11899
# 1  important --&gt; @JebBush suggests federal gov...    11899
# 2  important --&gt; @JebBush suggests federal gov...    11899
# 3  important --&gt; @JebBush suggests federal gov...    11899
# 4  @ChrisMara816: Screw #sandy we skipped right a...   116293
#
#                                          tweet_no_rt type_of_message_gold  \
# 0  important --&gt; @JebBush suggests federal gov...                  NaN
# 1  important --&gt; @JebBush suggests federal gov...                  NaN
# 2  important --&gt; @JebBush suggests federal gov...                  NaN
# 3  important --&gt; @JebBush suggests federal gov...                  NaN
# 4  @ChrisMara816: Screw #sandy we skipped right a...                  NaN
#
#         user
# 0  danholler
# 1  danholler
# 2  danholler
# 3  danholler
# 4  kaatteexo
#
# [5 rows x 23 columns]

# %%
dataset.shape
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7115 entries, 0 to 7114
# Data columns (total 23 columns):
#  #   Column                                                                Non-Null Count  Dtype
# ---  ------                                                                --------------  -----
#  0   _unit_id                                                              7115 non-null   int64
#  1   _created_at                                                           7115 non-null   object
#  2   _golden                                                               7115 non-null   bool
#  3   _id                                                                   7115 non-null   int64
#  4   _missed                                                               290 non-null    object
#  5   _started_at                                                           7115 non-null   object
#  6   _tainted                                                              7115 non-null   bool
#  7   _channel                                                              7115 non-null   object
#  8   _trust                                                                7115 non-null   float64
#  9   _worker_id                                                            7115 non-null   int64
#  10  _country                                                              7115 non-null   object
#  11  _region                                                               6945 non-null   object
#  12  _city                                                                 6945 non-null   object
#  13  _ip                                                                   7115 non-null   object
#  14  the_author_of_the_tweet_seems_to_be_an_eye_witness_of_the_event       485 non-null    object
#  15  type_of_message                                                       7115 non-null   object
#  16  nil                                                                   3 non-null      object
#  17  the_author_of_the_tweet_seems_to_be_an_eye_witness_of_the_event_gold  48 non-null     object
#  18  tweet                                                                 7115 non-null   object
#  19  tweet_no                                                              7115 non-null   int64
#  20  tweet_no_rt                                                           7115 non-null   object
#  21  type_of_message_gold                                                  1136 non-null   object
#  22  user                                                                  7115 non-null   object
# dtypes: bool(2), float64(1), int64(4), object(16)
# memory usage: 1.2+ MB

# %% [markdown]
# # Dataset 5
# 05_information_extraction/f157060.csv

# %%
dataset = ps.read_csv("SWDM2013_dataset/sandy2012_labeled_data/05_information_extraction/f157060.csv")
dataset.head()
# Out:
#     _unit_id        _created_at  _golden        _id _missed  \
# 0  240632763  1/2/2013 15:03:51     True  797143942   False
# 1  240632763  1/2/2013 15:06:13     True  797145153   False
# 2  240632763  1/2/2013 15:09:30     True  797146945   False
# 3  240632763  1/2/2013 15:20:43     True  797152214     NaN
# 4  240632763  1/2/2013 15:32:29     True  797157904     NaN
#
#          _started_at  _tainted _channel  _trust  _worker_id  ...  \
# 0  1/2/2013 15:01:51     False  instagc  0.9167    13441146  ...
# 1  1/2/2013 15:03:16     False  instagc  0.8750    14893322  ...
# 2  1/2/2013 15:06:41     False  instagc  1.0000    12960437  ...
# 3  1/2/2013 15:17:00     False  instagc  0.7500    14475081  ...
# 4  1/2/2013 15:30:17     False  instagc  1.0000    14049868  ...
#
#             _city             _ip  \
# 0       Cleveland    98.18.123.70
# 1       Lynchburg  96.235.212.161
# 2  Point Pleasant  173.81.178.140
# 3          Dunlap     98.143.6.78
# 4          Toledo   131.183.0.122
#
#                                  word_or_shortphrase  \
# 0  homes in the U.S. are now without power post-s...
# 1  8 million homes in the U.S. are now without power
# 2  8 million homes in the U.S. are now without power
# 3  8 million homes in the U.S. are now without power
# 4                                      without power
#
#                                          instruction  \
# 0  names a structure, road, service, line, etc. t...
# 1  names a structure, road, service, line, etc. t...
# 2  names a structure, road, service, line, etc. t...
# 3  names a structure, road, service, line, etc. t...
# 4  names a structure, road, service, line, etc. t...
#
#                                                tweet tweet_no  \
# 0  RT @nytimes: More than 8 million homes in the ...    53537
# 1  RT @nytimes: More than 8 million homes in the ...    53537
# 2  RT @nytimes: More than 8 million homes in the ...    53537
# 3  RT @nytimes: More than 8 million homes in the ...    53537
# 4  RT @nytimes: More than 8 million homes in the ...    53537
#
#                                          tweet_no_rt  \
# 0  More than 8 million homes in the U.S. are now ...
# 1  More than 8 million homes in the U.S. are now ...
# 2  More than 8 million homes in the U.S. are now ...
# 3  More than 8 million homes in the U.S. are now ...
# 4  More than 8 million homes in the U.S. are now ...
#
#                                      type_of_message  \
# 0  Informative: damage (building, road, lines, etc.)
# 1  Informative: damage (building, road, lines, etc.)
# 2  Informative: damage (building, road, lines, etc.)
# 3  Informative: damage (building, road, lines, etc.)
# 4  Informative: damage (building, road, lines, etc.)
#
#   type_of_messageconfidence                           word_or_shortphrase_gold
# 0                    0.6938  power\nwithout power\n8 million homes in the U...
# 1                    0.6938  power\nwithout power\n8 million homes in the U...
# 2                    0.6938  power\nwithout power\n8 million homes in the U...
# 3                    0.6938  power\nwithout power\n8 million homes in the U...
# 4                    0.6938  power\nwithout power\n8 million homes in the U...
#
# [5 rows x 22 columns]

# %%
dataset.shape
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2847 entries, 0 to 2846
# Data columns (total 22 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   _unit_id                   2847 non-null   int64
#  1   _created_at                2847 non-null   object
#  2   _golden                    2847 non-null   bool
#  3   _id                        2847 non-null   int64
#  4   _missed                    51 non-null     object
#  5   _started_at                2847 non-null   object
#  6   _tainted                   2847 non-null   bool
#  7   _channel                   2847 non-null   object
#  8   _trust                     2847 non-null   float64
#  9   _worker_id                 2847 non-null   int64
#  10  _country                   2847 non-null   object
#  11  _region                    2847 non-null   object
#  12  _city                      2847 non-null   object
#  13  _ip                        2847 non-null   object
#  14  word_or_shortphrase        2846 non-null   object
#  15  instruction                2847 non-null   object
#  16  tweet                      2847 non-null   object
#  17  tweet_no                   2847 non-null   int64
#  18  tweet_no_rt                2847 non-null   object
#  19  type_of_message            2847 non-null   object
#  20  type_of_messageconfidence  2847 non-null   float64
#  21  word_or_shortphrase_gold   341 non-null    object
# dtypes: bool(2), float64(2), int64(4), object(14)
# memory usage: 450.5+ KB

# %%
DS=dataset.drop({'_unit_id','_country','_missed','_started_at','_tainted','_channel','_golden','_id','_worker_id','word_or_shortphrase','tweet','tweet_no','type_of_messageconfidence','word_or_shortphrase_gold','_created_at','_trust','_region','_city','_ip'},axis=1)
DS.to_csv('instruction.csv')
